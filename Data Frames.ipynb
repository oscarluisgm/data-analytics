# %%
import sys
sys.path.append('/home/oscar/py_envs/lib/python3.12/site-packages')

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # DATAFRAME
#
# A Dataframe column is like a Serie

# %%
D=np.random.randint(100, size=(1,6), dtype="int8")

# %%
D
# Out:
# array([[47, 13, 54, 11, 68, 51]], dtype=int8)

# %%
df=pd.DataFrame({
    "Population" : [42, 63, 19, 76, 27,  8],
    "GDP" : [
        17648125,
        56894236,
        15182159,
        15418415,
        41541541,
        46549863
    ],
    "Surface Area":[
        151854,
        416414,
        4151664,
        251854,
        154185,
        1515
    ],
    "HDI":[
        0.91,
        0.89,
        0.88,
        0.90,
        0.897,
        0.91    
    ],
    "Continent":[
        "Europe",
        "America",
        "Asia",
        "America",
        "Europe",
        "America"
    ] 
}, columns=["Population", "GDP", "Surface Area", "HDI", "Continent"])

# the columns attribute is optional

# %%
df.index=["Germany","Argentina","Japan","United States","Italy","Canada"]

# %%
# A DataFrame is pretty much like a 2D NumPy array

df
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany                42  17648125        151854  0.910    Europe
# Argentina              63  56894236        416414  0.890   America
# Japan                  19  15182159       4151664  0.880      Asia
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe
# Canada                  8  46549863          1515  0.910   America

# %% [markdown]
# ## Pandas Functions

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent',
#        'GDP Per Capita', 'Language'],
#       dtype='object')

# %%
df.size
# Out:
# 30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Germany to Canada
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    6 non-null      int64
#  1   GDP           6 non-null      int64
#  2   Surface Area  6 non-null      int64
#  3   HDI           6 non-null      float64
#  4   Continent     6 non-null      object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 288.0+ bytes

# %%
df.shape
# Out:
# (6, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    6.000000  6.000000e+00  6.000000e+00  6.000000
# mean    39.166667  3.220572e+07  8.545810e+05  0.897833
# std     26.301458  1.836286e+07  1.620995e+06  0.011669
# min      8.000000  1.518216e+07  1.515000e+03  0.880000
# 25%     21.000000  1.597584e+07  1.524368e+05  0.891750
# 50%     34.500000  2.959483e+07  2.030195e+05  0.898500
# 75%     57.750000  4.529778e+07  3.752740e+05  0.907500
# max     76.000000  5.689424e+07  4.151664e+06  0.910000

# %%
# dtypes (pandas) not dtype as in numpy
# object in this case is a string basically

df.dtypes
# Out:
# Population        int64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      3
# float64    1
# object     1
# Name: count, dtype: int64

# %%
df
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany                42  17648125        151854  0.910    Europe
# Argentina              63  56894236        416414  0.890   America
# Japan                  19  15182159       4151664  0.880      Asia
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe
# Canada                  8  46549863          1515  0.910   America

# %% [markdown]
# ## Filtering in Pandas DataFrames (The returned results are Series)

# %% [markdown]
# ### By index

# %%
df.loc["Canada"]
# Out:
# Population             8
# GDP             46549863
# Surface Area        1515
# HDI                 0.91
# Continent        America
# Name: Canada, dtype: object

# %% [markdown]
# ### By sequential position

# %%
df.iloc[-1]
# Out:
# Population             8
# GDP             46549863
# Surface Area        1515
# HDI                 0.91
# Continent        America
# Name: Canada, dtype: object

# %% [markdown]
# ### By Column (Series in the DataFrame)

# %%
df["Population"]
# Out:
# Germany          42
# Argentina        63
# Japan            19
# United States    76
# Italy            27
# Canada            8
# Name: Population, dtype: int64

# %%
df
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany                42  17648125        151854  0.910    Europe
# Argentina              63  56894236        416414  0.890   America
# Japan                  19  15182159       4151664  0.880      Asia
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe
# Canada                  8  46549863          1515  0.910   America

# %%
#Prettier than just calling by column name
df["Population"].to_frame()
# Out:
#                Population
# Germany                42
# Argentina              63
# Japan                  19
# United States          76
# Italy                  27
# Canada                  8

# %% [markdown]
# ### Slicing

# %%
df[["Population","GDP"]]
# Out:
#                Population       GDP
# Germany                42  17648125
# Argentina              63  56894236
# Japan                  19  15182159
# United States          76  15418415
# Italy                  27  41541541
# Canada                  8  46549863

# %%
df.loc["Argentina":"Italy"]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Argentina              63  56894236        416414  0.890   America
# Japan                  19  15182159       4151664  0.880      Asia
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe

# %%
# WITH A SECOND DIMENSION
#loc just for objects (strings) 
          #Keys             #Columns value as a "list" in reality they are NumPy arrays
df.loc["Argentina":"Italy", ["Continent","Surface Area"]]
# Out:
#               Continent  Surface Area
# Argentina       America        416414
# Japan              Asia       4151664
# United States   America        251854
# Italy            Europe        154185

# %%
df.iloc[[0,2,3,-1]]
# Out:
#                Population       GDP  Surface Area   HDI Continent
# Germany                42  17648125        151854  0.91    Europe
# Japan                  19  15182159       4151664  0.88      Asia
# United States          76  15418415        251854  0.90   America
# Canada                  8  46549863          1515  0.91   America

# %%
#iloc just for numbers

df.iloc[0:3, 3]
# Out:
# Germany      0.91
# Argentina    0.89
# Japan        0.88
# Name: HDI, dtype: float64

# %% [markdown]
# ### Boolean Assessment

# %%
# RETURNS A SERIE

df["Population"] > 70
# Out:
# Germany          False
# Argentina        False
# Japan            False
# United States     True
# Italy            False
# Canada           False
# Name: Population, dtype: bool

# %% [markdown]
# ### Boolean filtering

# %%
# By Columns RETURNS A DATAFRAME

df[df["Population"]>70]
# Out:
#                Population       GDP  Surface Area  HDI Continent
# United States          76  15418415        251854  0.9   America

# %%
#By Columns but less code-efficient RETURNS A DATAFRAME

#Condition to asses the indexes, #The returns we want to see
df.loc[df["Population"]>50, ["GDP","HDI"]]
# Out:
#                     GDP   HDI
# Argentina      56894236  0.89
# United States  15418415  0.90

# %% [markdown]
# ### DROPPING (LIKE DISCARD)

# %%
#BY INDEX
df.drop(["Canada","Japan"])
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany                42  17648125        151854  0.910    Europe
# Argentina              63  56894236        416414  0.890   America
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe

# %%
#BY COLUMNS
df.drop(columns=["Population","GDP"])
# Out:
#                Surface Area    HDI Continent
# Germany              151854  0.910    Europe
# Argentina            416414  0.890   America
# Japan               4151664  0.880      Asia
# United States        251854  0.900   America
# Italy                154185  0.897    Europe
# Canada                 1515  0.910   America

# %% [markdown]
# ### OPERATIONS

# %%
#To broadcast or vectorize
crisis=pd.Series([-1_000_000,-0.3],index=["GDP","HDI"])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
#THE RESULT WILL BE WITH 1000000 less in GDP and 0.3 less in HDI
df[["GDP","HDI"]]+crisis
# Out:
#                       GDP    HDI
# Germany        16648125.0  0.610
# Argentina      55894236.0  0.590
# Japan          14182159.0  0.580
# United States  14418415.0  0.600
# Italy          40541541.0  0.597
# Canada         45549863.0  0.610

# %% [markdown]
# ### Modifying a frame

# %%
#This is for adding Japanese,English and Italian in the indexes Japan, United States and Italy with the name of the column "Languages"
langs=pd.Series(["Japanese","English","Italian"],
                 index=["Japan", "United States","Italy"],
                 name="Languages"
                 #name of the Series
               )

# %%
#Then adding a new column with the name "Language" and is gonna be equal to the "Series" langs 

df["Language"]=langs

# %%
#Finally, we call "df" and we are gonna retrieve a DataFrame with the previously added column called "Language" and all its respective added languages
df
# Out:
#                Population       GDP  Surface Area    HDI Continent  Language
# Germany                42  17648125        151854  0.910    Europe       NaN
# Argentina              63  56894236        416414  0.890   America       NaN
# Japan                  19  15182159       4151664  0.880      Asia  Japanese
# United States          76  15418415        251854  0.900   America   English
# Italy                  27  41541541        154185  0.897    Europe   Italian
# Canada                  8  46549863          1515  0.910   America       NaN

# %%
#To add the same string to all the rows in the column "Language" MUTABLE (REMAINS THE SAME DATAFRAME FROM NOW ON)
df["Language"]="Lang"

# %%
df
# Out:
#                Population       GDP  Surface Area    HDI Continent Language
# Germany                42  17648125        151854  0.910    Europe     Lang
# Argentina              63  56894236        416414  0.890   America     Lang
# Japan                  19  15182159       4151664  0.880      Asia     Lang
# United States          76  15418415        251854  0.900   America     Lang
# Italy                  27  41541541        154185  0.897    Europe     Lang
# Canada                  8  46549863          1515  0.910   America     Lang

# %%
# ".RENAME() METHOD" TO MODIFY THE NAMES OF THE COLUMNS AND INDEXES
# Not mutable
df.rename(
    columns={
        "HDI":"Human Development Index",
        "Anual Popcorn Consumption":"APC"
        #This last one is one example that doesn't modify anything
    },
    index={
        "USA":"United States",
        "UK":"United Kingdom"
    }
    
)
# Out:
#                Population       GDP  Surface Area  Human Development Index  \
# Germany                42  17648125        151854                    0.910
# Argentina              63  56894236        416414                    0.890
# Japan                  19  15182159       4151664                    0.880
# United States          76  15418415        251854                    0.900
# Italy                  27  41541541        154185                    0.897
# Canada                  8  46549863          1515                    0.910
#
#               Continent Language
# Germany          Europe     Lang
# Argentina       America     Lang
# Japan              Asia     Lang
# United States   America     Lang
# Italy            Europe     Lang
# Canada          America     Lang

# %%
df
# Out:
#                Population       GDP  Surface Area    HDI Continent Language
# Germany                42  17648125        151854  0.910    Europe     Lang
# Argentina              63  56894236        416414  0.890   America     Lang
# Japan                  19  15182159       4151664  0.880      Asia     Lang
# United States          76  15418415        251854  0.900   America     Lang
# Italy                  27  41541541        154185  0.897    Europe     Lang
# Canada                  8  46549863          1515  0.910   America     Lang

# %% [markdown]
# ### Adding a new column with an operation between the existing columns

# %%
df["GDP Per Capita"]= df["GDP"]/df["Population"]
df
# Out:
#                Population       GDP  Surface Area    HDI Continent Language  \
# Germany                42  17648125        151854  0.910    Europe     Lang
# Argentina              63  56894236        416414  0.890   America     Lang
# Japan                  19  15182159       4151664  0.880      Asia     Lang
# United States          76  15418415        251854  0.900   America     Lang
# Italy                  27  41541541        154185  0.897    Europe     Lang
# Canada                  8  46549863          1515  0.910   America     Lang
#
#                GDP Per Capita
# Germany          4.201935e+05
# Argentina        9.030831e+05
# Japan            7.990610e+05
# United States    2.028739e+05
# Italy            1.538576e+06
# Canada           5.818733e+06

# %%
df.head()
# Out:
#                Population       GDP  Surface Area    HDI Continent Language  \
# Germany                42  17648125        151854  0.910    Europe     Lang
# Argentina              63  56894236        416414  0.890   America     Lang
# Japan                  19  15182159       4151664  0.880      Asia     Lang
# United States          76  15418415        251854  0.900   America     Lang
# Italy                  27  41541541        154185  0.897    Europe     Lang
#
#                GDP Per Capita
# Germany          4.201935e+05
# Argentina        9.030831e+05
# Japan            7.990610e+05
# United States    2.028739e+05
# Italy            1.538576e+06

# %%
#Just a "Series"
df["GDP"]/df["Population"]
# Out:
# Germany          4.201935e+05
# Argentina        9.030831e+05
# Japan            7.990610e+05
# United States    2.028739e+05
# Italy            1.538576e+06
# Canada           5.818733e+06
# dtype: float64

# %%
df.rename(index=str.upper)
# Out:
#                Population       GDP  Surface Area    HDI Continent Language  \
# GERMANY                42  17648125        151854  0.910    Europe     Lang
# ARGENTINA              63  56894236        416414  0.890   America     Lang
# JAPAN                  19  15182159       4151664  0.880      Asia     Lang
# UNITED STATES          76  15418415        251854  0.900   America     Lang
# ITALY                  27  41541541        154185  0.897    Europe     Lang
# CANADA                  8  46549863          1515  0.910   America     Lang
#
#                GDP Per Capita
# GERMANY          4.201935e+05
# ARGENTINA        9.030831e+05
# JAPAN            7.990610e+05
# UNITED STATES    2.028739e+05
# ITALY            1.538576e+06
# CANADA           5.818733e+06

# %%
df.rename(index=lambda x:x.capitalize())
# Out:
#                Population       GDP  Surface Area    HDI Continent Language  \
# Germany                42  17648125        151854  0.910    Europe     Lang
# Argentina              63  56894236        416414  0.890   America     Lang
# Japan                  19  15182159       4151664  0.880      Asia     Lang
# United states          76  15418415        251854  0.900   America     Lang
# Italy                  27  41541541        154185  0.897    Europe     Lang
# Canada                  8  46549863          1515  0.910   America     Lang
#
#                GDP Per Capita
# Germany          4.201935e+05
# Argentina        9.030831e+05
# Japan            7.990610e+05
# United states    2.028739e+05
# Italy            1.538576e+06
# Canada           5.818733e+06

# %%
df.rename(index=str.lower)
# Out:
#                Population       GDP  Surface Area    HDI Continent Language  \
# germany                42  17648125        151854  0.910    Europe     Lang
# argentina              63  56894236        416414  0.890   America     Lang
# japan                  19  15182159       4151664  0.880      Asia     Lang
# united states          76  15418415        251854  0.900   America     Lang
# italy                  27  41541541        154185  0.897    Europe     Lang
# canada                  8  46549863          1515  0.910   America     Lang
#
#                GDP Per Capita
# germany          4.201935e+05
# argentina        9.030831e+05
# japan            7.990610e+05
# united states    2.028739e+05
# italy            1.538576e+06
# canada           5.818733e+06

# %%
#DROP WITH "INPLACE" IF IT'S TRUE IT'S MUTABLE AND THEN YOU DON'T HAVE THE COLUMN YOU DROPPED AGAIN 

#IN THIS CASE IT'S FALSE SO YOU RETRIEVE IT WITHOUT THE COLUMN ONCE BUT IT'S STILL IN THE ORIGINAL DATAFRAME

df.drop(columns="Language", inplace=False)
# Out:
#                Population       GDP  Surface Area    HDI Continent  \
# Germany                42  17648125        151854  0.910    Europe
# Argentina              63  56894236        416414  0.890   America
# Japan                  19  15182159       4151664  0.880      Asia
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe
# Canada                  8  46549863          1515  0.910   America
#
#                GDP Per Capita
# Germany          4.201935e+05
# Argentina        9.030831e+05
# Japan            7.990610e+05
# United States    2.028739e+05
# Italy            1.538576e+06
# Canada           5.818733e+06

# %%
df
# Out:
#                Population       GDP  Surface Area    HDI Continent  \
# Germany                42  17648125        151854  0.910    Europe
# Argentina              63  56894236        416414  0.890   America
# Japan                  19  15182159       4151664  0.880      Asia
# United States          76  15418415        251854  0.900   America
# Italy                  27  41541541        154185  0.897    Europe
# Canada                  8  46549863          1515  0.910   America
#
#                GDP Per Capita  Language
# Germany          4.201935e+05       NaN
# Argentina        9.030831e+05       NaN
# Japan            7.990610e+05  Japanese
# United States    2.028739e+05   English
# Italy            1.538576e+06   Italian
# Canada           5.818733e+06       NaN

# %%
#TO ADD A NEW INDEX WITH VALUES FOR THE COLUMNS WE WANNA ADD

China= pd.DataFrame({"Population":[3], "GDP":[5]}, index=["China"])

# %%
#APPEND IS DEPRECATED
#CONCAT IS NOT MUTABLE SO IT CHANGES ONCE AND RETRIEVES ONCES
pd.concat([df,China])
# Out:
#                Population         GDP  Surface Area    HDI Continent  \
# Germany                42  17648125.0      151854.0  0.910    Europe
# Argentina              63  56894236.0      416414.0  0.890   America
# Japan                  19  15182159.0     4151664.0  0.880      Asia
# United States          76  15418415.0      251854.0  0.900   America
# Italy                  27  41541541.0      154185.0  0.897    Europe
# Canada                  8  46549863.0        1515.0  0.910   America
# China                1400         NaN           NaN    NaN      Asia
# China                   3         5.0           NaN    NaN       NaN
#
#                GDP Per Capita  Language
# Germany          4.201935e+05       NaN
# Argentina        9.030831e+05       NaN
# Japan            7.990610e+05  Japanese
# United States    2.028739e+05   English
# Italy            1.538576e+06   Italian
# Canada           5.818733e+06       NaN
# China                     NaN       NaN
# ...

# %%
#MUTABLE SO IT CHANGES THE ORIGINAL
df.loc["China"]=pd.Series({"Population":1400,"Continent":"Asia"})

# %%
df
# Out:
#                Population         GDP  Surface Area    HDI Continent  \
# Germany                42  17648125.0      151854.0  0.910    Europe
# Argentina              63  56894236.0      416414.0  0.890   America
# Japan                  19  15182159.0     4151664.0  0.880      Asia
# United States          76  15418415.0      251854.0  0.900   America
# Italy                  27  41541541.0      154185.0  0.897    Europe
# Canada                  8  46549863.0        1515.0  0.910   America
# China                1400         NaN           NaN    NaN      Asia
#
#                GDP Per Capita  Language
# Germany          4.201935e+05       NaN
# Argentina        9.030831e+05       NaN
# Japan            7.990610e+05  Japanese
# United States    2.028739e+05   English
# Italy            1.538576e+06   Italian
# Canada           5.818733e+06       NaN
# China                     NaN       NaN

# %%
#TO RESET AND SHOW THE NUMERICAL INDEXES
df.reset_index()
# Out:
#            index  Population         GDP  Surface Area    HDI Continent  \
# 0        Germany          42  17648125.0      151854.0  0.910    Europe
# 1      Argentina          63  56894236.0      416414.0  0.890   America
# 2          Japan          19  15182159.0     4151664.0  0.880      Asia
# 3  United States          76  15418415.0      251854.0  0.900   America
# 4          Italy          27  41541541.0      154185.0  0.897    Europe
# 5         Canada           8  46549863.0        1515.0  0.910   America
# 6          China        1400         NaN           NaN    NaN      Asia
#
#    GDP Per Capita  Language
# 0    4.201935e+05       NaN
# 1    9.030831e+05       NaN
# 2    7.990610e+05  Japanese
# 3    2.028739e+05   English
# 4    1.538576e+06   Italian
# 5    5.818733e+06       NaN
# 6             NaN       NaN

# %%
df
# Out:
#                Population         GDP  Surface Area    HDI Continent  \
# Germany                42  17648125.0      151854.0  0.910    Europe
# Argentina              63  56894236.0      416414.0  0.890   America
# Japan                  19  15182159.0     4151664.0  0.880      Asia
# United States          76  15418415.0      251854.0  0.900   America
# Italy                  27  41541541.0      154185.0  0.897    Europe
# Canada                  8  46549863.0        1515.0  0.910   America
# China                1400         NaN           NaN    NaN      Asia
#
#                GDP Per Capita  Language
# Germany          4.201935e+05       NaN
# Argentina        9.030831e+05       NaN
# Japan            7.990610e+05  Japanese
# United States    2.028739e+05   English
# Italy            1.538576e+06   Italian
# Canada           5.818733e+06       NaN
# China                     NaN       NaN

# %%
#TO SEE POPULATION AS THE INDEX COLUMN ONCE (MUTABLE)
df.set_index("Population")
# Out:
#                    GDP  Surface Area    HDI Continent  GDP Per Capita  \
# Population
# 42          17648125.0      151854.0  0.910    Europe    4.201935e+05
# 63          56894236.0      416414.0  0.890   America    9.030831e+05
# 19          15182159.0     4151664.0  0.880      Asia    7.990610e+05
# 76          15418415.0      251854.0  0.900   America    2.028739e+05
# 27          41541541.0      154185.0  0.897    Europe    1.538576e+06
# 8           46549863.0        1515.0  0.910   America    5.818733e+06
# 1400               NaN           NaN    NaN      Asia             NaN
#
#             Language
# Population
# 42               NaN
# 63               NaN
# 19          Japanese
# 76           English
# 27           Italian
# 8                NaN
# 1400             NaN

# %%
df
# Out:
#                Population         GDP  Surface Area    HDI Continent  \
# Germany                42  17648125.0      151854.0  0.910    Europe
# Argentina              63  56894236.0      416414.0  0.890   America
# Japan                  19  15182159.0     4151664.0  0.880      Asia
# United States          76  15418415.0      251854.0  0.900   America
# Italy                  27  41541541.0      154185.0  0.897    Europe
# Canada                  8  46549863.0        1515.0  0.910   America
# China                1400         NaN           NaN    NaN      Asia
#
#                GDP Per Capita  Language
# Germany          4.201935e+05       NaN
# Argentina        9.030831e+05       NaN
# Japan            7.990610e+05  Japanese
# United States    2.028739e+05   English
# Italy            1.538576e+06   Italian
# Canada           5.818733e+06       NaN
# China                     NaN       NaN

# %%
population=df["Population"]

# %%
#This is the artithmetic MEAN
population.sum()/len(population)
# Out:
# np.float64(233.57142857142858)

# %%
#You can prove it here
population.mean()
# Out:
# np.float64(233.57142857142858)

# %%
population.min(),population.max()
# Out:
# (np.int64(8), np.int64(1400))

# %%
population.std()
# Out:
# np.float64(514.9067414405762)

# %%
population.median()
# Out:
# np.float64(42.0)

# %%
#SORTED ASCENDING
population.sort_values()
# Out:
# Canada              8
# Japan              19
# Italy              27
# Germany            42
# Argentina          63
# United States      76
# China            1400
# Name: Population, dtype: int64

# %%
#SORTED DESCENDING
population.sort_values(ascending=False)
# Out:
# China            1400
# United States      76
# Argentina          63
# Germany            42
# Italy              27
# Japan              19
# Canada              8
# Name: Population, dtype: int64

# %%
df
# Out:
#                Population         GDP  Surface Area    HDI Continent  \
# Germany                42  17648125.0      151854.0  0.910    Europe
# Argentina              63  56894236.0      416414.0  0.890   America
# Japan                  19  15182159.0     4151664.0  0.880      Asia
# United States          76  15418415.0      251854.0  0.900   America
# Italy                  27  41541541.0      154185.0  0.897    Europe
# Canada                  8  46549863.0        1515.0  0.910   America
# China                1400         NaN           NaN    NaN      Asia
#
#                GDP Per Capita  Language
# Germany          4.201935e+05       NaN
# Argentina        9.030831e+05       NaN
# Japan            7.990610e+05  Japanese
# United States    2.028739e+05   English
# Italy            1.538576e+06   Italian
# Canada           5.818733e+06       NaN
# China                     NaN       NaN

# %%
population.quantile(.25)
# Out:
# np.float64(23.0)

# %%
population.quantile(.1)
# Out:
# np.float64(14.600000000000001)

# %%
population.quantile(.35)
# Out:
# np.float64(28.499999999999993)
